# %% [markdown]
# # P2. Exploration Python

# %% [markdown]
# Le répertoire `/data` contient les résultats brutes des épreuves des jeux d'été et d'hiver pour une période donnée.
#
# On s'intéresse dans le cadre de cette partie P2 à l'exploration des résultats des JO d'été (fichier : `summer-olympics.csv`) en s'appuyant sur le langage Python (standard library seulement).

# %% [markdown]
# ---

# %% [markdown]
# ## Préliminaire: Chargement des données
# Le code fourni ci-dessous permet de charger en mémoire le fichier de données `summer-olympics.csv` dans la variable `data`

# %%
import csv
import time

filename = 'data/summer-olympics.csv'

ts = time.time()

data = []
with open(filename, newline='') as csvfile:
    reader = csv.DictReader(csvfile, delimiter=',')
    for row in reader:
        data.append(row)
n_items = len(data)

te = time.time()
        
print(f"{filename} loaded into data ({n_items} items)")
print(f"done in {te - ts:.2f} s.")
# Out:
# data/summer-olympics.csv loaded into data (31165 items)
# done in 0.49 s.

# %% [markdown]
# ### Question 0: Où trouver la documentation du module `csv` ? de la fonction `csv.DictReader` ?

# %% [markdown]
# [lien doc python3] (https://docs.python.org/3/library/csv.html)

# %% [markdown]
# même lien qu'au dessus.

# %% [markdown]
# ---
# ### Question 1: Quel est le type de la variable `data`?

# %%
type(data)
# Out:
# list

# %% [markdown]
# ### Question 2: Combien d'éléments contient la variable `data` ?

# %%
len(data)
# Out:
# 31165

# %% [markdown]
# ### Question 2: Quel est le premier élément de `data` ?

# %%
data[0]
# Out:
# {'Year': '1896',
#  'City': 'Athens',
#  'Sport': 'Aquatics',
#  'Discipline': 'Swimming',
#  'Athlete': 'HAJOS, Alfred',
#  'Country': 'HUN',
#  'Gender': 'Men',
#  'Event': '100M Freestyle',
#  'Medal': 'Gold'}

# %% [markdown]
# ### Question 3: Quel est le dernier élément de data ?

# %%
data[-1]
# Out:
# {'Year': '2012',
#  'City': 'London',
#  'Sport': 'Wrestling',
#  'Discipline': 'Wrestling Freestyle',
#  'Athlete': 'LIDBERG, Jimmy',
#  'Country': 'SWE',
#  'Gender': 'Men',
#  'Event': 'Wg 96 KG',
#  'Medal': 'Bronze'}

# %% [markdown]
# ---
# #### On définit la variable sample de la façon suivante :

# %%
sample = data[25215]

# %% [markdown]
# ### Question 4: Que représente la variable `sample` ?

# %%
sample
# Out:
# {'Year': '2004',
#  'City': 'Athens',
#  'Sport': 'Aquatics',
#  'Discipline': 'Swimming',
#  'Athlete': 'MANAUDOU, Laure',
#  'Country': 'FRA',
#  'Gender': 'Women',
#  'Event': '100M Backstroke',
#  'Medal': 'Bronze'}

# %% [markdown]
# ### Question 5: Quel est le type de la variable `sample` ?

# %%
type(sample)
# Out:
# dict

# %% [markdown]
# ### Question 6: De quel sport / discipline / compétition (Event) est-il question  ?

# %%
sample["Sport"]
# Out:
# 'Aquatics'

# %%
sample["Discipline"]
# Out:
# 'Swimming'

# %%
sample["Event"]
# Out:
# '100M Backstroke'

# %% [markdown]
# ### Question 5: Quel est le type de la variable `sample` ?

# %%
count =0

for item in data :
    if item['Medal'] == 'Gold' and item['Country'] == 'FRA' and item['Year'] == '1984':
        count +=1
   
print(count)
# Out:
# 21

# %%
count =0

for item in data :
    if item['Country'] == 'JPN' and item['Year'] == '2012':
        count +=1
   
print(count)
# Out:
# 84

# %%
selection = []
for e in data:
    if e['Year'] == '2012' and e['Medal'] == 'Gold':
        selection.append(e)
len(selection)

pays = []

for e2 in selection:
    if e2['Country'] :
        pays.append(e2)
    
print(len(pays))
# Out:
#   File "<ipython-input-32-8fb7fbea305a>", line 10
#     if e2['Country'] is not:
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Q3

# %%
selection = []
for e in data:
    if e['Gender'] == 'Women' and e['Medal']:
        selection.append(e)
len(selection)
# Out:
# 8419

# %% [markdown]
# ### Q4

# %%
selection = []
for e in data:
    if e['Gender'] == 'Women' and e['Medal'] == 'Gold':
        selection.append(e)
len(selection)
# Out:
# 2788

# %% [markdown]
# ### Q5

# %%
selection = []
for e in data:
    if e['Gender'] == 'Women' and e['Medal'] == 'Gold':
        selection.append(e)
len(selection)

# %%
selection = []
for e in data:
    if e['City'] == 'London' and e['Year'] == '1908':
        selection.append(e)
len(selection)
# Out:
# 0

# %% [markdown]
# ### Question i:

# %% [markdown]
# ---

# %% [markdown]
# Fin
